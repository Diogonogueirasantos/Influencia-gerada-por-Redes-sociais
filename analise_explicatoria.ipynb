# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Dataset e analogos/final_version_DF.csv')

# %%
df.head()
# Out:
#    Idade    Genero  Tempo de Uso em Redes Sociais  \
# 0     25  Feminino                            7.0
# 1     50  Feminino                            2.0
# 2     35  Feminino                            4.0
# 3     30  Feminino                            2.0
# 4     22  Feminino                            2.0
#
#    Numero de Plataformas Usadas Frenquencia de Posts  \
# 0                             5            Raramente
# 1                             4            Raramente
# 2                             2            Raramente
# 3                             2            Raramente
# 4                             3        Algumas vezes
#
#    Frequencia de Posts (Ordinal) Frequencia de Verificacao por Notificacoes  \
# 0                            2.0                             Frequentimente
# 1                            2.0                             Frequentimente
# 2                            2.0                             Frequentimente
# ...

# %%
df.shape
# Out:
# (10137, 16)

# %%
O_3 = df.loc[df['Genero'] == 'Outro']

# %%
O_3 = df.loc[(df['Idade'] >= 23) & (df['Idade'] <= )]
